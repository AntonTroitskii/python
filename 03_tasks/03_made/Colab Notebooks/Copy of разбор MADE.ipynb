# %% [markdown]
# <img src="https://i.ibb.co/YtZCL7k/01.png"  width = 500/>

# %% [markdown]
# В первой задачи не понял условие умножается $33$ раза само на себя или всё таки "дошел он аж до $33$ степени"
#
# #### Ответ дал $30$ (не уверен)

# %% [markdown]
# <img src="https://i.ibb.co/vB86TRG/02.png"  width = 500/>

# %% [markdown]
# Вторая задача простая, достаточно было нарисовать сетку с узлами. В узлы ставить числа, которые равны сумме идущих чисел из других узлов
#
# #### Ответ: 429 (уверен)

# %% [markdown]
# <img src="https://i.ibb.co/x88VYdW/03.png"  width = 500/>

# %% [markdown]
# Задача школьная. Для начала $275=11\cdot5^2$. Далее находим на что оканчивается
# ### $$3^{1000}-2$$
#
# ### $3^{1}$ оканчивается на $3$
#
# ### $3^{2}$ оканчивается на $9$
#
# ### $3^{3}$ оканчивается на $7$
#
# ### $3^{4}$ оканчивается на $1$
#
# ### $3^{5}$ оканчивается на $3$
#
# Период равен $4$, значит
#
# ### $3^{1000}-2$ оканчивается на $9$
#
# Далее ищем остатки от деления $5$ на $275$
#
#
#
# ### $5^{*******9}\%275=225$
#
# #### Ответ: 225 (исправили)

# %% [markdown]
# <img src="https://i.ibb.co/k6drWjF/04.png"  width = 500/>

# %% [markdown]
# Задача простая. Умножаем вероятности на дискретную величину.
#
# ### $$m(X_i)=\frac{125}{216}\cdot0+\frac{20\cdot3}{216}\cdot2000+\frac{5\cdot3}{216}\cdot2500+\frac{5\cdot3}{216}\cdot3000+\frac{1}{216}\cdot4000$$
#
# В качестве проверки все вероятности в сумме должны давать $1$
#
# #### Ответ: 956 (уверен)

# %%
(125*0+60*2000+15*2500+15*3000+1*4000)/216
# Out:
# 956.0185185185185

# %% [markdown]
# <img src="https://i.ibb.co/sV9dn5g/05.png"  width = 500/>

# %% [markdown]
# ### $$x^2-63x+a=0$$
#
# ### $$\Bigl(x-\frac{63}{2}\Bigr)^2=\frac{3969}{4}-a$$
#
# ### $$x_1=\frac{63-\sqrt{3969-4a}}{2}\,\,\,\,\,\,x_2=\frac{63+\sqrt{3969-4a}}{2}$$
#
# Если корни целые, то по любому один получается четным. $2$ - единственное четное простое число. Очевидно, что это $x_1$, но проще подставить в исходное уравнение.
#
# ### $$2^2-63\cdot2+a=0$$
#
# ### $$a=122$$
#
# Для проверки корни $x_1=2$ и $x_2=61$ Оба простые
#
# #### Ответ: 122 (уверен)

# %% [markdown]
# <img src="https://i.ibb.co/PQpxfd3/06.png"  width = 500/>

# %% [markdown]
# Привести к диагональному виду, найти условие на ранги матриц
#
# ### $$9-a^2=0 \,\,\,\,\,\,\, 3a+9\neq0$$
#
# ### $$a=\pm3 \,\,\,\,\,\,\, a\neq-3$$
#
# #### Ответ: 3 (уверен)

# %% [markdown]
# <img src="https://i.ibb.co/yn4Zgsq/07.png"  width = 500/>

# %% [markdown]
# Зачем задача на эконометрику, если в demo её не было? :-)
#
# В ответе не уверен, могу только предполагать.
#
# #### Дал ответ $5,23$, возможно правильный  $5,96$ или где-то в этом диапазоне (не уверен)

# %%
import math

n = 10
Sx1 = 3860
Sx2 = 4574802

m = Sx1/n

s = (Sx2-m**2)/(n-1)

sln = math.log(s/m**2+1)

mln = math.log(m)-sln/2

print (f'{mln} или {math.log(Sx1/n)}')
# Out:
# 5.2264756827405225 или 5.955837369464831

# %% [markdown]
# <img src="https://i.ibb.co/Gpg5hDs/08.png"  width = 500/>

# %% [markdown]
# В чате кто-то спорил про некорректность условия непрерывной функции. Условие нормальное, т.к. кривую не задают, а просят найти. Т.е. её можно было найти только на $R^+$
#
# Тут получается задача Коши из уравнения касательной:
#
# ### $$2x=y+x\cdot y'\,\,\,\,\,\,\,y(1)=2$$
#
# Решение
#
# ### $$y=\frac{1}{x}+x$$
#
# #### Ответ: 5,2 (уверен)

# %% [markdown]
# <img src="https://i.ibb.co/Sf5c2NS/09.png"  width = 500/>

# %% [markdown]
# Задача школьная.
#
# Первая производная равна функции изменения тангенса. С помощью еще одной производной находим локальный максимум $x=-\frac{1}{\sqrt3}$ и локальный минимум $x=\frac{1}{\sqrt3}$.
#
# Следовательно наибольшее значение может быть в $x=-\frac{1}{\sqrt3}$ или при $x\to +\infty$
#
# Получаем
#
# ### $$8\cdot\Bigl(-\frac{1}{\sqrt3}\Bigr)\cdot\frac{3}{4}\cdot\frac{\sqrt3}{2}=-3$$
#
# #### Ответ: -3 (уверен)

# %% [markdown]
# <img src="https://i.ibb.co/ZzW2RQ2/10.png"  width = 500/>

# %% [markdown]
# Не совсем понял условие задачи. Скорее всего психолог приглашает пары случайным образом, иначе ответ был бы довольно простым $3$.
#
# #### Предположил, что ответ $5\cdot5+1=26$ (не уверен)
